# %% [markdown]
# #### Edge Detection
#
# - whenever we have a grayscale image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/lenna.png',0)

# %%
# Sobel parameters: ksize, dx, dy, ddepth

sobelx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3) # Sobel for horizontal edges
sobely = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3) # Sobel for Vertical edges

#Cpmbine the Sobel images(optional)

combined_sobel = cv2.add(sobelx, sobely)

# %%
thresh, binary_sobel = cv2.threshold(combined_sobel, 120, 255, cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,4,1)
plt.title('Original Image')
plt.imshow(image,cmap='gray')
plt.subplot(1,4,2)
plt.title('sobelx Image')
plt.imshow(sobelx,cmap='gray')
plt.subplot(1,4,3)
plt.title('sobely Image')
plt.imshow(sobely,cmap='gray')
plt.subplot(1,4,4)
plt.title('combined_sobel')
plt.imshow(combined_sobel,cmap='gray')

# %%
img1 = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/lenna.png')
img2 = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/sun.png')
# img2 = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/spiderman.jpg')

# %%
# img2 = img2.reshape(512,512) #for spiderman.jpg
img1.shape, img2.shape
# Out:
# ((512, 512, 3), (512, 512, 3))

# %%
new_img = cv2.add(img1, img2)
final_img = np.hstack([img1, img2, new_img])

# for spiderman.jpg
# new_img = cv2.add(img1, img2[:513,:513])
# final_img = np.hstack([img1, img2[512,512], new_img])

# %%
cv2.imshow("Added Image", final_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Canny Edge Detection

# %%
#Apply canny edge detection
edges = cv2.Canny(image, 50, 150)

#Display the image
cv2.imshow("Orig Image", image)
cv2.imshow("Canny Image", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(image,cmap='gray')
plt.subplot(1,3,2)
plt.title('Final Sobel')
plt.imshow(binary_sobel,cmap='gray')
plt.subplot(1,3,3)
plt.title('Canny Image')
plt.imshow(edges,cmap='gray')

# %%
image = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/circle.png',0)

# %%
# Sobel parameters: ksize, dx, dy, ddepth

sobelx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3) # Sobel for horizontal edges
sobely = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3) # Sobel for Vertical edges

#Combine the Sobel images(optional)
combined_sobel = cv2.add(sobelx, sobely)

plt.figure(figsize=(16,8))
plt.subplot(1,4,1)
plt.title('Original Image')
plt.imshow(image,cmap='gray')
plt.subplot(1,4,2)
plt.title('sobelx Image')
plt.imshow(sobelx,cmap='gray')
plt.subplot(1,4,3)
plt.title('sobely Image')
plt.imshow(sobely,cmap='gray')
plt.subplot(1,4,4)
plt.title('combined_sobel')
plt.imshow(combined_sobel,cmap='gray')

# %%
#Binary Sobel
thresh, binary_sobel = cv2.threshold(combined_sobel, 120, 255, cv2.THRESH_BINARY)

#Apply Canny egde detection
edges = cv2.Canny(image, 50, 150)

plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(image,cmap='gray')
plt.subplot(1,3,2)
plt.title('Final Sobel')
plt.imshow(binary_sobel,cmap='gray')
plt.subplot(1,3,3)
plt.title('Canny Image')
plt.imshow(edges,cmap='gray')

# %% [markdown]
# ##### Harris Corner Detector

# %%
import cv2
import numpy as np

#Load the image
gray = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/circle.png',0)
image = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/circle.png')

# Convert image into dloat32
gray = np.float32(gray)

#Apply the Harris Corner detector
dst = cv2.cornerHarris(gray,blockSize=2,ksize=3,k=0.04)

# Result is dilated for marking the corners, not important
dst = cv2.dilate(dst, None)

#Threshold for an optimal value, it may vary depending on the image.
image[dst > 0.01 * dst.max()] = [0, 0, 255]

cv2.imshow("Harris Corners", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Load the image
gray = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/lenna.png',0)
image = cv2.imread('/home/pgdai/Desktop/March24-DAI-Workspace/CV-June24/images/lenna.png')

# Convert image into dloat32
gray = np.float32(gray)

#Apply the Harris Corner detector
dst = cv2.cornerHarris(gray,blockSize=2,ksize=3,k=0.04)

# Result is dilated for marking the corners, not important
dst = cv2.dilate(dst, None)

#Threshold for an optimal value, it may vary depending on the image.
image[dst > 0.01 * dst.max()] = [0, 0, 255]

cv2.imshow("Harris Corners", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
